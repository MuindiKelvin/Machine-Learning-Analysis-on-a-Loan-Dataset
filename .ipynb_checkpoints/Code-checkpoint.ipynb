# %% [markdown]
# <h1 style="color:blue">ICA-CIS4035-N-Machine-Learning-2023-2024</h1>

# %% [markdown]
# <h1 style="color:blue">Project: Loan Classification in Machine Learning</h1>

# %% [markdown]
# <h2 style="color:blue">Library Imports</h2>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import scipy.sparse as sparse
from sklearn.impute import SimpleImputer
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve, auc

# %% [markdown]
# <h2 style="color:blue">Dataset Loading</h2>

# %%
# Load the dataset
df = pd.read_csv('Data/loan.csv')

# %% [markdown]
# <h2 style="color:blue">EDA and Visualizations</h2>

# %%
# Explore the dataset
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
# Plot histogram for loan_amnt
plt.figure(figsize=(10, 6))
sns.histplot(df['loan_amnt'], bins=30, kde=True)
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()

# Plot histogram for int_rate
plt.figure(figsize=(10, 6))
sns.histplot(df['int_rate'], bins=30, kde=True)
plt.title('Interest Rate Distribution')
plt.xlabel('Interest Rate')
plt.ylabel('Frequency')
plt.show()

# Plot histogram for installment
plt.figure(figsize=(10, 6))
sns.histplot(df['installment'], bins=30, kde=True)
plt.title('Installment Distribution')
plt.xlabel('Installment')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot: loan_amnt by grade
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='grade', y='loan_amnt')
plt.title('Loan Amount Distribution by Grade')
plt.xlabel('Grade')
plt.ylabel('Loan Amount')
plt.show()

# %% [markdown]
# <h2 style="color:blue">Data Preparation and Processing</h2>

# %%
# Split data into features and target
X = df.drop('loan_status', axis=1)  # Features
y = df['loan_status']  # Target variable (Accepted/Rejected)

# %%
# Encode categorical variables
categorical_cols = [col for col in X.columns if X[col].dtype == 'object']
print(f'Categorical columns: {categorical_cols}')
# Out:
# Categorical columns: ['term', 'int_rate', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'revol_util', 'initial_list_status', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d', 'application_type']

# %%
# One-hot encode categorical variables
encoder = OneHotEncoder(handle_unknown='ignore')
X_encoded_cat = encoder.fit_transform(X[categorical_cols])

# %%
# Dropping the original categorical columns
X_encoded = X.drop(categorical_cols, axis=1)

# Combining the encoded columns with the numerical columns
if isinstance(X_encoded, pd.DataFrame):
    X_encoded = sparse.csr_matrix(X_encoded.values)

X_encoded = sparse.hstack([X_encoded, X_encoded_cat])

# %%
# Splitting data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Creating an imputer object
imputer = SimpleImputer(strategy='mean')  # 'median' or 'most_frequent' can also be used

# Fit the imputer on the training data and transform both training and test data
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
from sklearn.impute import SimpleImputer

# Instantiating SimpleImputer to replace NaN values with the mean
imputer = SimpleImputer(strategy='mean')

# Fitting and transforming the imputer on the training data
X_train_imputed = imputer.fit_transform(X_train)

# Transforming the test data using the fitted imputer
X_test_imputed = imputer.transform(X_test)

# %% [markdown]
# <h2 style="color:blue"> Modeling</h2>

# %%
# Train and evaluate Logistic Regression model
print('Logistic Regression')
log_reg = LogisticRegression()
log_reg.fit(X_train_imputed, y_train)  # or X_train_clean, y_train_clean
y_pred = log_reg.predict(X_test_imputed)  # or X_test_clean
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.9587109768378651
# Classification Report:
#                precision    recall  f1-score   support
#
#  Charged Off       0.94      0.91      0.92      1094
#      Current       0.74      0.42      0.54       262
#   Fully Paid       0.97      0.99      0.98      6588
#
#     accuracy                           0.96      7944
#    macro avg       0.88      0.77      0.81      7944
# weighted avg       0.96      0.96      0.96      7944

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
# Train and evaluate Decision Tree Classifier
print('\nDecision Tree Classifier')
dt_clf = DecisionTreeClassifier()
# Train the decision tree classifier on the imputed training data
dt_clf.fit(X_train_imputed, y_train)
# Make predictions on the imputed test data
y_pred = dt_clf.predict(X_test_imputed)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Decision Tree Classifier
# Accuracy: 0.9934541792547835
# Classification Report:
#                precision    recall  f1-score   support
#
#  Charged Off       0.99      0.96      0.98      1094
#      Current       1.00      1.00      1.00       262
#   Fully Paid       0.99      1.00      1.00      6588
#
#     accuracy                           0.99      7944
#    macro avg       1.00      0.99      0.99      7944
# weighted avg       0.99      0.99      0.99      7944

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
# Train and evaluate Random Forest Classifier
print('\nRandom Forest Classifier')
random_forest = RandomForestClassifier()
# Train the Random Forest classifier on the imputed training data
random_forest.fit(X_train_imputed, y_train)
# Make predictions on the imputed test data
y_pred = random_forest.predict(X_test_imputed)
# Generate classification report
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Random Forest Classifier
# Accuracy: 0.9763343403826787
# Classification Report:
#                precision    recall  f1-score   support
#
#  Charged Off       1.00      0.83      0.91      1094
#      Current       1.00      1.00      1.00       262
#   Fully Paid       0.97      1.00      0.99      6588
#
#     accuracy                           0.98      7944
#    macro avg       0.99      0.94      0.96      7944
# weighted avg       0.98      0.98      0.98      7944

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %% [markdown]
# <h2 style="color:blue">Comparison of Classification Accuracy</h2>

# %%
from sklearn.metrics import accuracy_score

# Train and evaluate Logistic Regression model
log_reg = LogisticRegression()
log_reg.fit(X_train_imputed, y_train)
y_pred_log_reg = log_reg.predict(X_test_imputed)
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg)

# Train and evaluate Decision Tree Classifier
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train_imputed, y_train)
y_pred_dt_clf = dt_clf.predict(X_test_imputed)
accuracy_dt_clf = accuracy_score(y_test, y_pred_dt_clf)

# Train and evaluate Random Forest Classifier
random_forest = RandomForestClassifier()
random_forest.fit(X_train_imputed, y_train)
y_pred_random_forest = random_forest.predict(X_test_imputed)
accuracy_random_forest = accuracy_score(y_test, y_pred_random_forest)

# Compare accuracy scores
print('Accuracy Scores:')
print('Logistic Regression:', accuracy_log_reg)
print('Decision Tree Classifier:', accuracy_dt_clf)
print('Random Forest Classifier:', accuracy_random_forest)

# Identify and print the best performing model
best_model = max(accuracy_log_reg, accuracy_dt_clf, accuracy_random_forest)
if best_model == accuracy_log_reg:
    print('Best Performing Model: Logistic Regression')
elif best_model == accuracy_dt_clf:
    print('Best Performing Model: Decision Tree Classifier')
else:
    print('Best Performing Model: Random Forest Classifier')
# Out:
# Accuracy Scores:
# Logistic Regression: 0.9587109768378651
# Decision Tree Classifier: 0.9928247734138973
# Random Forest Classifier: 0.9750755287009063
# Best Performing Model: Decision Tree Classifier
